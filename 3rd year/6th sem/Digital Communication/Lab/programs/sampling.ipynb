# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.arange(0,1,0.01) # (start,end-1,step)

f = 1

T = 1/f # time period sy pata lagega time period 2 means 2 second my ek wave complete hogi


# print(t)
x  = np.sin(2*np.pi*f*t)



# plt.plot(t,x)
# plt.grid() # grid lines banjayegi
# plt.legend("1")
# plt.xlim(0,0.5) # set the viewing limit of graph

# print(x)
# Out:
# [ 0.00000000e+00  0.00000000e+00  1.25333234e-01  0.00000000e+00
#   2.48689887e-01  0.00000000e+00  3.68124553e-01  0.00000000e+00
#   4.81753674e-01  0.00000000e+00  5.87785252e-01  0.00000000e+00
#   6.84547106e-01  0.00000000e+00  7.70513243e-01  0.00000000e+00
#   8.44327926e-01  0.00000000e+00  9.04827052e-01  0.00000000e+00
#   9.51056516e-01  0.00000000e+00  9.82287251e-01  0.00000000e+00
#   9.98026728e-01  0.00000000e+00  9.98026728e-01  0.00000000e+00
#   9.82287251e-01  0.00000000e+00  9.51056516e-01  0.00000000e+00
#   9.04827052e-01  0.00000000e+00  8.44327926e-01  0.00000000e+00
#   7.70513243e-01  0.00000000e+00  6.84547106e-01  0.00000000e+00
#   5.87785252e-01  0.00000000e+00  4.81753674e-01  0.00000000e+00
#   3.68124553e-01  0.00000000e+00  2.48689887e-01  0.00000000e+00
#   1.25333234e-01  0.00000000e+00  1.22464680e-16  0.00000000e+00
#  -1.25333234e-01  0.00000000e+00 -2.48689887e-01  0.00000000e+00
# ...

# %%
# isko sample karna hai

xs = np.zeros_like(x) # kisi dusre array ki length ky brabar ki array with zero

# original array sy sample lena hai

# (starting pos, ending pos-1,updater,incrementer)

for i in range(0,len(x),5): # sampling -> har 3 sample lega
    xs[i] = x[i] 




# print(xs)

plt.plot(t,x)

plt.stem(t,xs,'r')
plt.grid()
plt.xlabel("Sampling ")
# Out:
# Text(0.5, 0, 'Sampling ')

# %%
# taking fft of signal 
temp = [1,2,3,4,5]
x_fft = np.fft.fft(temp) # discreate time fourier trasformation

print(x_fft)
# Out:
# [15. +0.j         -2.5+3.4409548j  -2.5+0.81229924j -2.5-0.81229924j
#  -2.5-3.4409548j ]
